# %%
# Install required packages with user flag
# %pip install --user --force-reinstall matplotlib==3.10.0
# %pip install --user ydata-profiling

# Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport

# Read the data
df = pd.read_csv('train.csv')

# Create profile report
profile = ProfileReport(df, title="Titanic Dataset Profiling Report")

# Display the report in notebook
profile.to_notebook_iframe()

# Can also save as HTML file
profile.to_file("titanic_profile_report.html")
# Out:
# ...
#   Using cached matplotlib-3.10.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.1-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.56.0-cp312-cp312-win_amd64.whl.metadata (103 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# ...
#   Using cached numpy-2.2.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached pillow-11.1.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Using cached matplotlib-3.10.0-cp312-cp312-win_amd64.whl (8.0 MB)
# Using cached contourpy-1.3.1-cp312-cp312-win_amd64.whl (220 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...

# %%
df=pd.read_csv('train.csv')
df.head
# Out:
# <bound method NDFrame.head of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# Install required packages
# %pip install pandas-profiling

# Import pandas profiling
# from ydata_profiling import ProfileReport
# Install ydata-profiling
# %pip install ydata-profiling




# Create profile report
profile = ProfileReport(df, title="Titanic Dataset Profiling Report")

# Display the report in notebook
profile.to_notebook_iframe()

# Can also save as HTML file
profile.to_file("titanic_profile_report.html")
# Out:
# ...
#   Using cached matplotlib-3.10.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# ...
# Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# Using cached matplotlib-3.10.1-cp312-cp312-win_amd64.whl (8.1 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\MARUF HASAN\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\MARUF HASAN\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\MARUF HASAN\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\Users\\MARUF HASAN\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\backends\\_backend_agg.cp312-win_amd64.pyd'
# ...
